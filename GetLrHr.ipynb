# %%
import yaml

# Reading a Pahts YAML file of OTSR
yaml_path = r'C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\OTSR_dev\code\preprocess\paths.yml'
with open(yaml_path, 'r') as file:
    paths = yaml.safe_load(file)

import os

# Specify the path for the new folder
Currupted_te_y = r'C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\DataSets\Currupted-te-y' 
Currupted_va_x = r'C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\DataSets\Currupted-va-x'
# Create the new folder
os.makedirs(Currupted_te_y, exist_ok=True)
os.makedirs(Currupted_va_x, exist_ok=True)

paths["df2k"]["tdsr"]['source'] = r"C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\DataSets\Currupted-te-x"
paths["df2k"]["tdsr"]["target"] = Currupted_te_y
paths["df2k"]["tdsr"]["valid"] = Currupted_va_x
paths["datasets"]["df2k"] = r"C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\DataSets\DF2K"
paths["datasets"]["dped"] = r"C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\DataSets\DPED"

# Writing to a YAML file
with open(yaml_path, 'w') as file:
    yaml.dump(paths, file, default_flow_style=False)

# %%
# Generate validation dataset
# !python C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\OTSR_dev\code\preprocess\creat_validation.py --dataset df2k

# !python C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\OTSR_dev\code\preprocess\collect_noise.py --dataset df2k --artifact tdsr
# there is no noise in the image so we are getting zero noise patches
# Out:
# C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\OTSR_dev\code\preprocess\creat_validation.py:22: SyntaxWarning: invalid escape sequence '\S'
#   with open('C:\SaiVinay\Thesis\Git_Hub_Thesis\OTSR_dev\code\preprocess\paths.yml', 'r') as stream:
#
# ...
# Generating images from validation: 100%|██████████| 100/100 [00:07<00:00, 13.52it/s]
# C:\SaiVinay\SproutsAI\GitHub_\ir_srgan_otsr\gans_project\DataSets\DF2K\Corrupted_noise
# Total images: 100
# ********** 0901 **********
# Image size: (510, 338)
# patch shape: (256, 256)
# Mean global: 109.77305603027344
# Mean throshold: 10.977305603027345
# Var throshold: 99.13862481055548
# Mean local: 133.65966796875
# Var local: 83.70253348350525
# count: 0
# Patchs: 0
# ********** 0902 **********
# Image size: (510, 338)
# patch shape: (256, 256)
# Mean global: 63.88533020019531
# Mean throshold: 6.388533020019532
# Var throshold: 511.4810533769778
# Mean local: 31.330078125
# Var local: 33.195247650146484
# count: 0
# Patchs: 0
# ...

# %%
# !pip install pillow
